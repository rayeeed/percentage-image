# %% [markdown]
# <a href="https://colab.research.google.com/github/rayeeed/percentage-image/blob/main/Copy_of_ThesisPercentageRayeed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The code based on this notebook available here
# https://github.com/CSAILVision/semantic-segmentation-pytorch/tree/master/notebooks
#
# It can be run on Colab at this URL https://colab.research.google.com/github/CSAILVision/semantic-segmentation-pytorch/blob/master/notebooks/DemoSegmenter.ipynb

# %% [markdown]
# ### Environment Setup
#
# First, download the code and pretrained models if we are on colab.

# %%
# %%bash
# # Colab-specific setup
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# pip install yacs 2>&1 >> install.log
# git init 2>&1 >> install.log
# git remote add origin https://github.com/CSAILVision/semantic-segmentation-pytorch.git 2>> install.log
# git pull origin master 2>&1 >> install.log
# DOWNLOAD_ONLY=1 ./demo_test.sh 2>> install.log
# Out:
# From https://github.com/CSAILVision/semantic-segmentation-pytorch
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master

# %% [markdown]
# ## Imports and utility functions
#
# We need pytorch, numpy, and the code for the segmentation model.  And some utilities for visualizing the data.

# %%
# System libs
import os, csv, torch, numpy, scipy.io, PIL.Image, torchvision.transforms, glob, cv2, re
# Our libs
from mit_semseg.models import ModelBuilder, SegmentationModule
from mit_semseg.utils import colorEncode

colors = scipy.io.loadmat('data/color150.mat')['colors']
names = {}
with open('data/object150_info.csv') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        names[int(row[0])] = row[5].split(";")[0]
        
print(names)
len(names)
def visualize_result(img, pred, index=None):
    # filter prediction class if requested
    if index is not None:
        pred = pred.copy()
        pred[pred != index] = -1
        print(f'{names[index+1]}:')
        
    # colorize prediction
    pred_color = colorEncode(pred, colors).astype(numpy.uint8)

    # aggregate images and save
    im_vis = numpy.concatenate((img, pred_color), axis=1)
    display(PIL.Image.fromarray(im_vis))

def frameImage(img):
    lst=[]
    pil_to_tensor = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(
        mean=[0.485, 0.456, 0.406], # These are RGB mean+std values
        std=[0.229, 0.224, 0.225])  # across a large photo dataset.
    ])
    pil_image = PIL.Image.open(img).convert('RGB')
    img_original = numpy.array(pil_image)
    img_data = pil_to_tensor(pil_image)
    singleton_batch = {'img_data': img_data[None].cuda()}
    output_size = img_data.shape[1:]

    # Run the segmentation at the highest resolution.
    with torch.no_grad():
        scores = segmentation_module(singleton_batch, segSize=output_size)
        
    # Get the predicted scores for each pixel
    _, pred = torch.max(scores, dim=1)
    pred = pred.cpu()[0].numpy()
    dim= pred.shape[0]*pred.shape[1]
    pred=pred.flatten()
    

    res = re.findall('grid-(\d+)-(\d+).jpg', os.path.basename(img))
    lst.append(int(res[0][0])) #insert grid number to the list
    lst.append(os.path.basename(img)) #insert image name to the list


    bin_arr = numpy.bincount(pred)
    predicted_classes = numpy.bincount(pred.flatten()).argsort()[::-1]
    for i in range(150):
        if i in predicted_classes:
          count = bin_arr[i]
          percentage= round(count*100/dim,2)
          lst.append(percentage) #inserting percentage values of each classes
          #print(str(names.get(i+1))  + ' is ' + str(percentage))
        else:
          #print(str(names.get(i+1))  + ' is ' + str(0.0))
          lst.append(0.0)
    df_length = len(df)
    df.loc[df_length] = lst #inserting the lst data of an image to the overall dataframe
# Out:
# {1: 'wall', 2: 'building', 3: 'sky', 4: 'floor', 5: 'tree', 6: 'ceiling', 7: 'road', 8: 'bed', 9: 'windowpane', 10: 'grass', 11: 'cabinet', 12: 'sidewalk', 13: 'person', 14: 'earth', 15: 'door', 16: 'table', 17: 'mountain', 18: 'plant', 19: 'curtain', 20: 'chair', 21: 'car', 22: 'water', 23: 'painting', 24: 'sofa', 25: 'shelf', 26: 'house', 27: 'sea', 28: 'mirror', 29: 'rug', 30: 'field', 31: 'armchair', 32: 'seat', 33: 'fence', 34: 'desk', 35: 'rock', 36: 'wardrobe', 37: 'lamp', 38: 'bathtub', 39: 'railing', 40: 'cushion', 41: 'base', 42: 'box', 43: 'column', 44: 'signboard', 45: 'chest', 46: 'counter', 47: 'sand', 48: 'sink', 49: 'skyscraper', 50: 'fireplace', 51: 'refrigerator', 52: 'grandstand', 53: 'path', 54: 'stairs', 55: 'runway', 56: 'case', 57: 'pool', 58: 'pillow', 59: 'screen', 60: 'stairway', 61: 'river', 62: 'bridge', 63: 'bookcase', 64: 'blind', 65: 'coffee', 66: 'toilet', 67: 'flower', 68: 'book', 69: 'hill', 70: 'bench', 71: 'countertop', 72: 'stove', 73: 'palm', 74: 'kitchen', 75: 'computer', 76: 'swivel', 77: 'boat', 78: 'bar', 79: 'arcade', 80: 'hovel', 81: 'bus', 82: 'towel', 83: 'light', 84: 'truck', 85: 'tower', 86: 'chandelier', 87: 'awning', 88: 'streetlight', 89: 'booth', 90: 'television', 91: 'airplane', 92: 'dirt', 93: 'apparel', 94: 'pole', 95: 'land', 96: 'bannister', 97: 'escalator', 98: 'ottoman', 99: 'bottle', 100: 'buffet', 101: 'poster', 102: 'stage', 103: 'van', 104: 'ship', 105: 'fountain', 106: 'conveyer', 107: 'canopy', 108: 'washer', 109: 'plaything', 110: 'swimming', 111: 'stool', 112: 'barrel', 113: 'basket', 114: 'waterfall', 115: 'tent', 116: 'bag', 117: 'minibike', 118: 'cradle', 119: 'oven', 120: 'ball', 121: 'food', 122: 'step', 123: 'tank', 124: 'trade', 125: 'microwave', 126: 'pot', 127: 'animal', 128: 'bicycle', 129: 'lake', 130: 'dishwasher', 131: 'screen', 132: 'blanket', 133: 'sculpture', 134: 'hood', 135: 'sconce', 136: 'vase', 137: 'traffic', 138: 'tray', 139: 'ashcan', 140: 'fan', 141: 'pier', 142: 'crt', 143: 'plate', 144: 'monitor', 145: 'bulletin', 146: 'shower', 147: 'radiator', 148: 'glass', 149: 'clock', 150: 'flag'}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
net_encoder = ModelBuilder.build_encoder(
    arch='resnet50dilated',
    fc_dim=2048,
    weights='ckpt/ade20k-resnet50dilated-ppm_deepsup/encoder_epoch_20.pth')
net_decoder = ModelBuilder.build_decoder(
    arch='ppm_deepsup',
    fc_dim=2048,
    num_class=150,
    weights='ckpt/ade20k-resnet50dilated-ppm_deepsup/decoder_epoch_20.pth',
    use_softmax=True)

crit = torch.nn.NLLLoss(ignore_index=-1)
segmentation_module = SegmentationModule(net_encoder, net_decoder, crit)
segmentation_module.eval()
segmentation_module.cuda()
# Out:
# Loading weights for net_encoder
# Loading weights for net_decoder
# SegmentationModule(
#   (encoder): ResnetDilated(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#     (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn3): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#     (relu3): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(64, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(128, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): SynchronizedBatchNorm2d(256, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(1024, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(2048, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): SynchronizedBatchNorm2d(2048, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(2048, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): SynchronizedBatchNorm2d(2048, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (decoder): PPMDeepsup(
#     (ppm): ModuleList(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#       )
#     )
#     (cbr_deepsup): Sequential(
#       (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv_last): Sequential(
#       (0): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): SynchronizedBatchNorm2d(512, eps=1e-05, momentum=0.001, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout2d(p=0.1, inplace=False)
#       (4): Conv2d(512, 150, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (conv_last_deepsup): Conv2d(512, 150, kernel_size=(1, 1), stride=(1, 1))
#     (dropout_deepsup): Dropout2d(p=0.1, inplace=False)
#   )
#   (crit): NLLLoss()
# )

# %%
import pandas as pd
df=pd.DataFrame()
df = df.join(pd.DataFrame(columns= ['grid','imagename']))
df = df.join(pd.DataFrame(columns=names.values()))
df
# Out:
# Empty DataFrame
# Columns: [grid, imagename, wall, building, sky, floor, tree, ceiling, road, bed, windowpane, grass, cabinet, sidewalk, person, earth, door, table, mountain, plant, curtain, chair, car, water, painting, sofa, shelf, house, sea, mirror, rug, field, armchair, seat, fence, desk, rock, wardrobe, lamp, bathtub, railing, cushion, base, box, column, signboard, chest, counter, sand, sink, skyscraper, fireplace, refrigerator, grandstand, path, stairs, runway, case, pool, pillow, screen, stairway, river, bridge, bookcase, blind, coffee, toilet, flower, book, hill, bench, countertop, stove, palm, kitchen, computer, swivel, boat, bar, arcade, hovel, bus, towel, light, truck, tower, chandelier, awning, streetlight, booth, television, airplane, dirt, apparel, pole, land, bannister, escalator, ottoman, ...]
# Index: []
#
# [0 rows x 152 columns]

# %%
for file in glob.glob("/content/drive/MyDrive/location 9639-13500/*.jpg"):
    print('\n'+" start of image " + str(file) +'\n')
    frameImage(file)
# Out:
# Streaming output truncated to the last 5000 lines.
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10928-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10928-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10928-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10929-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10929-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10929-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10929-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10930-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10930-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10931-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10930-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10930-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10931-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10931-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10931-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10932-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10932-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10933-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10932-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10932-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10933-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10933-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10934-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10933-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10934-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10934-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10934-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10935-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10935-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10935-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10935-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10936-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10936-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10937-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10936-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10936-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10937-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10937-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10937-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10938-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10938-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10938-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10938-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10939-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10939-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10940-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10939-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10939-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10940-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10940-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10940-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10941-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10941-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10941-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10941-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10942-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10942-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10943-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10942-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10942-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10943-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10943-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10943-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10944-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10944-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10944-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10945-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10944-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10945-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10945-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10946-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10945-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10946-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10946-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10946-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10947-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10947-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10947-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10947-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10948-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10948-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10948-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10948-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10949-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10949-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10949-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10949-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10950-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10950-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10950-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10950-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10951-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10951-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10951-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10951-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10952-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10952-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10952-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10952-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10953-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10953-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10953-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10954-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10954-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10953-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10954-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10954-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10955-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10955-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10956-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10955-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10955-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10956-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10956-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10956-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10957-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10957-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10957-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10957-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10958-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10958-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10958-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10958-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10959-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10959-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10959-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10959-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10960-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10960-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10960-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10960-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10961-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10961-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10961-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10961-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10962-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10962-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10962-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10962-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10963-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10963-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10963-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10963-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10964-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10964-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10964-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10964-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10965-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10965-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10965-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10966-0.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10965-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10966-180.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10966-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10966-270.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-10967-90.jpg
#
#
#  start of image /content/drive/MyDrive/location 9639-13500/grid-
# 10113   9692   grid-9692-180.jpg   0.00      1.34  ...       0.0    0.0    0.0   0.0
# 10114   9692    grid-9692-90.jpg   0.00      0.00  ...       0.0    0.0    0.0   0.0
# 10115   9692   grid-9692-270.jpg   0.00      4.87  ...       0.0    0.0    0.0   0.0
#
# [10116 rows x 152 columns]

# %%
indexNames = df[ (df['sky'] == 84.95) & (df['floor'] == 13.54)].index #My dataset had blank images which would give out these values for these two parameters
df1=df.drop(indexNames)

# %%
df1
# Out:
#         grid           imagename   wall  building  ...  radiator  glass  clock  flag
# 56     12830    grid-12830-0.jpg   8.70     17.93  ...       0.0    0.0    0.0  0.00
# 57     12830   grid-12830-90.jpg  17.31     23.07  ...       0.0    0.0    0.0  0.00
# 58     12830  grid-12830-180.jpg   0.03     94.73  ...       0.0    0.0    0.0  0.01
# 59     12830  grid-12830-270.jpg   0.33     34.10  ...       0.0    0.0    0.0  0.00
# 87     12838    grid-12838-0.jpg   0.37     16.71  ...       0.0    0.0    0.0  0.01
# ...      ...                 ...    ...       ...  ...       ...    ...    ...   ...
# 10111   9676   grid-9676-270.jpg  26.16      0.02  ...       0.0    0.0    0.0  0.00
# 10112   9692     grid-9692-0.jpg   0.00      0.00  ...       0.0    0.0    0.0  0.00
# 10113   9692   grid-9692-180.jpg   0.00      1.34  ...       0.0    0.0    0.0  0.00
# 10114   9692    grid-9692-90.jpg   0.00      0.00  ...       0.0    0.0    0.0  0.00
# 10115   9692   grid-9692-270.jpg   0.00      4.87  ...       0.0    0.0    0.0  0.00
#
# [2176 rows x 152 columns]

# %% [markdown]
# For my project, I needed to pool 4 images of same grids together as averaged value. Ignore this segment if it's not necessary for you.

# %%
blank_rows= df.shape[0]-df1.shape[0]
blank_grid= blank_rows/4
total_grid= df.shape[0]/4
percent_blank= round((blank_grid/total_grid)*100,2)
print("percentage of blank grid is: %f" %(percent_blank))
# Out:
# percentage of blank grid is: 78.490000

# %%
grouped_df1 = df1.groupby('grid').mean() 
grouped_df1
# Out:
#          wall  building      sky   floor  ...  radiator  glass  clock   flag
# grid                                      ...
# 9639   3.1625    6.3175  37.8475   0.000  ...       0.0    0.0    0.0  0.000
# 9640   1.3500    0.0000  84.7600  13.840  ...       0.0    0.0    0.0  0.000
# 9641   1.3500    0.0000  84.7600  13.840  ...       0.0    0.0    0.0  0.000
# 9642   1.3500    0.0000  84.7600  13.840  ...       0.0    0.0    0.0  0.000
# 9643   1.3500    0.0000  84.7600  13.840  ...       0.0    0.0    0.0  0.000
# ...       ...       ...      ...     ...  ...       ...    ...    ...    ...
# 12920  0.0425    4.5925  41.7950   0.000  ...       0.0    0.0    0.0  0.000
# 12937  2.8300   39.0275  16.6300   0.130  ...       0.0    0.0    0.0  0.040
# 12976  0.0700    5.1800  44.2625   0.195  ...       0.0    0.0    0.0  0.000
# 13011  0.5925    9.2925  31.5400   0.000  ...       0.0    0.0    0.0  0.000
# 13021  0.9025   33.0400  36.9525   0.000  ...       0.0    0.0    0.0  0.015
#
# [544 rows x 150 columns]

# %%
grouped_df1.to_csv('/content/data/extractedData9.5-13.5.csv',index=True)
